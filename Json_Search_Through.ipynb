# %%
import json

# %%
with open('AllPrintings.json', encoding = 'utf-8') as f:
    all_data = json.loads(f.read())

# %%
for each in all_data['data']['ZEN']['cards']:
    print(each['name'])
    print(each.keys())
    print(each['purchaseUrls'])
# Out:
# Armament Master
# dict_keys(['artist', 'availability', 'boosterTypes', 'borderColor', 'colorIdentity', 'colors', 'convertedManaCost', 'edhrecRank', 'finishes', 'flavorText', 'foreignData', 'frameVersion', 'hasFoil', 'hasNonFoil', 'identifiers', 'language', 'layout', 'legalities', 'manaCost', 'manaValue', 'name', 'number', 'originalText', 'originalType', 'power', 'printings', 'purchaseUrls', 'rarity', 'rulings', 'setCode', 'subtypes', 'supertypes', 'text', 'toughness', 'type', 'types', 'uuid'])
# {'cardKingdom': 'https://mtgjson.com/links/b6a83fed0b547002', 'cardKingdomFoil': 'https://mtgjson.com/links/e9119fa5cb0b7a97', 'cardmarket': 'https://mtgjson.com/links/f7d431ba3e956b8a', 'tcgplayer': 'https://mtgjson.com/links/f1175384534cdb6e'}
# Arrow Volley Trap
# ...
